# %%
import sys
print(sys.executable)
# Out:
# c:\Information_Retrivial_System\venv\Scripts\python.exe

# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
print(GOOGLE_API_KEY)
# Out:
# AIzaSyAzgJIhW_eI4LqYMTNeCKCFMyrSqSWd0n0
